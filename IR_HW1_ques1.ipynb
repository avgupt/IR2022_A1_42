# %% [markdown]
# # Unzip Data

# %%
#unzip data

from google.colab import drive
drive.mount('/content/gdrive')
# !unzip gdrive/My\ Drive/data/Humor,Hist,Media,Food.zip
# Out:
# Mounted at /content/gdrive
# Archive:  gdrive/My Drive/data/Humor,Hist,Media,Food.zip
#    creating: Humor,Hist,Media,Food/
#   inflating: Humor,Hist,Media,Food/apsnet.txt
#   inflating: Humor,Hist,Media,Food/basehead.txt
#   inflating: Humor,Hist,Media,Food/c0dez.txt
#   inflating: Humor,Hist,Media,Food/chickenheadbbs.txt
#   inflating: Humor,Hist,Media,Food/cybrtrsh.txt
#   inflating: Humor,Hist,Media,Food/dalive
#   inflating: Humor,Hist,Media,Food/deadlysins.txt
#   inflating: Humor,Hist,Media,Food/draxamus.txt
#   inflating: Humor,Hist,Media,Food/exidy.txt
#   inflating: Humor,Hist,Media,Food/exylic.txt
#   inflating: Humor,Hist,Media,Food/golnar.txt
#   inflating: Humor,Hist,Media,Food/hack7.txt
#   inflating: Humor,Hist,Media,Food/hackingcracking.txt
#   inflating: Humor,Hist,Media,Food/hackmorality.txt
#   inflating: Humor,Hist,Media,Food/happyhack.txt
#   inflating: Humor,Hist,Media,Food/hermsys.txt
#   inflating: Humor,Hist,Media,Food/heroic.txt
#   inflating: Humor,Hist,Media,Food/iremember
#   inflating: Humor,Hist,Media,Food/jayjay.txt
#   inflating: Humor,Hist,Media,Food/jimhood.txt
#   inflating: Humor,Hist,Media,Food/jon.txt
#   inflating: Humor,Hist,Media,Food/kilroy
#   inflating: Humor,Hist,Media,Food/lansing.txt
#   inflating: Humor,Hist,Media,Food/lifeonledge.txt
#   inflating: Humor,Hist,Media,Food/lipkovits.txt
#   inflating: Humor,Hist,Media,Food/mindvox
#   inflating: Humor,Hist,Media,Food/minn.txt
#   inflating: Humor,Hist,Media,Food/modemwld.txt
#   inflating: Humor,Hist,Media,Food/mog-history
#   inflating: Humor,Hist,Media,Food/namaste.txt
#   inflating: Humor,Hist,Media,Food/nameisreo.txt
#   inflating: Humor,Hist,Media,Food/necropls.txt
#   inflating: Humor,Hist,Media,Food/netmask.txt
#   inflating: Humor,Hist,Media,Food/onan.txt
#   inflating: Humor,Hist,Media,Food/pat.txt
#   inflating: Humor,Hist,Media,Food/phxbbs-m.txt
#   inflating: Humor,Hist,Media,Food/planetzero.txt
#   inflating: Humor,Hist,Media,Food/proudlyserve.txt
#   inflating: Humor,Hist,Media,Food/radexposed.txt
#   inflating: Humor,Hist,Media,Food/reeves.txt
#   inflating: Humor,Hist,Media,Food/sawyer.txt
#   inflating: Humor,Hist,Media,Food/silverclaws.txt
#   inflating: Humor,Hist,Media,Food/stressman.txt
#   inflating: Humor,Hist,Media,Food/thievco.txt
#   inflating: Humor,Hist,Media,Food/three.txt
#   inflating: Humor,Hist,Media,Food/ukunderg.txt
#   inflating: Humor,Hist,Media,Food/whatbbs
#   inflating: Humor,Hist,Media,Food/yuban.txt
#   inflating: Humor,Hist,Media,Food/trekfume.txt
#   inflating: Humor,Hist,Media,Food/trekwes.hum
#   inflating: Humor,Hist,Media,Food/trukdeth.txt
#   inflating: Humor,Hist,Media,Food/truthlsd.hum
#   inflating: Humor,Hist,Media,Food/truths.hum
#   inflating: Humor,Hist,Media,Food/t-shirt.hum
#   inflating: Humor,Hist,Media,Food/turbo.hum
#   inflating: Humor,Hist,Media,Food/turing.shr
#   inflating: Humor,Hist,Media,Food/twinkie.txt
#   inflating: Humor,Hist,Media,Food/unochili.txt
#   inflating: Humor,Hist,Media,Food/t_zone.jok
#   inflating: Humor,Hist,Media,Food/univ.odd
#   inflating: Humor,Hist,Media,Food/urban.txt
#   inflating: Humor,Hist,Media,Food/vaguemag.90s
#   inflating: Humor,Hist,Media,Food/valujet.txt
#   inflating: Humor,Hist,Media,Food/variety1.asc
#   inflating: Humor,Hist,Media,Food/variety2.asc
#   inflating: Humor,Hist,Media,Food/variety3.asc
#   inflating: Humor,Hist,Media,Food/vegkill.txt
#   inflating: Humor,Hist,Media,Food/voltron.hum
#   inflating: Humor,Hist,Media,Food/vonthomp
#   inflating: Humor,Hist,Media,Food/wagon.hum
#   inflating: Humor,Hist,Media,Food/waitress.txt
#   inflating: Humor,Hist,Media,Food/washroom.txt
#   inflating: Humor,Hist,Media,Food/wedding.hum
#   inflating: Humor,Hist,Media,Food/weight.txt
#   inflating: Humor,Hist,Media,Food/welfare
#   inflating: Humor,Hist,Media,Food/welfare.txt
#   inflating: Humor,Hist,Media,Food/wetdream.hum
#   inflating: Humor,Hist,Media,Food/who.txt
#   inflating: Humor,Hist,Media,Food/whoon1st.hum
#   inflating: Humor,Hist,Media,Food/whoops.hum
#   inflating: Humor,Hist,Media,Food/why-me.hum
#   inflating: Humor,Hist,Media,Food/wimptest.txt
#   inflating: Humor,Hist,Media,Food/wisconsi.txt
#   inflating: Humor,Hist,Media,Food/wisdom
#   inflating: Humor,Hist,Media,Food/women.jok
#   inflating: Humor,Hist,Media,Food/wood
#   inflating: Humor,Hist,Media,Food/woodbine.txt
#   inflating: Humor,Hist,Media,Food/woodbugs.txt
#   inflating: Humor,Hist,Media,Food/woodsmok.txt
#   inflating: Humor,Hist,Media,Food/woolly_m.amm
#   inflating: Humor,Hist,Media,Food/word.hum
#   inflating: Humor,Hist,Media,Food/wrdnws1.txt
#   inflating: Humor,Hist,Media,Food/wrdnws2.txt
#   inflating: Humor,Hist,Media,Food/wrdnws3.txt
#   inflating: Humor,Hist,Media,Food/wrdnws4.txt
#   inflating: Humor,Hist,Media,Food/wrdnws5.txt
#   inflating: Humor,Hist,Media,Food/wrdnws6.txt
#   inflating: Humor,Hist,Media,Food/wrdnws7.txt
#   inflating: Humor,Hist,Media,Food/wrdnws8.txt
#   inflating: Humor,Hist,Media,Food/wrdnws9.txt
#   inflating: Humor,Hist,Media,Food/xibovac.txt
#   inflating: Humor,Hist,Media,Food/xtermin8.hum
#   inflating: Humor,Hist,Media,Food/y.txt
#   inflating: Humor,Hist,Media,Food/yjohncse.hum
#   inflating: Humor,Hist,Media,Food/yogisays.txt
#   inflating: Humor,Hist,Media,Food/yuppies.hum
#   inflating: Humor,Hist,Media,Food/zen.txt
#   inflating: Humor,Hist,Media,Food/zgtoilet.txt
#   inflating: Humor,Hist,Media,Food/zodiac.hum
#   inflating: Humor,Hist,Media,Food/snipe.txt
#   inflating: Humor,Hist,Media,Food/soccer.txt
#   inflating: Humor,Hist,Media,Food/socecon.hum
#   inflating: Humor,Hist,Media,Food/social.hum
#   inflating: Humor,Hist,Media,Food/socks.drx
#   inflating: Humor,Hist,Media,Food/solviets.hum
#   inflating: Humor,Hist,Media,Food/some_hu.mor
#   inflating: Humor,Hist,Media,Food/speling.msk
#   inflating: Humor,Hist,Media,Food/spelin_r.ifo
#   inflating: Humor,Hist,Media,Food/spider.hum
#   inflating: Humor,Hist,Media,Food/spoonlis.txt
#   inflating: Humor,Hist,Media,Food/spydust.hum
#   inflating: Humor,Hist,Media,Food/squids.gph
#   inflating: Humor,Hist,Media,Food/staff.txt
#   inflating: Humor,Hist,Media,Food/standard.hum
#   inflating: Humor,Hist,Media,Food/startrek.txt
#   inflating: Humor,Hist,Media,Food/stereo.txt
#   inflating: Humor,Hist,Media,Food/steroid.txt
#   inflating: Humor,Hist,Media,Food/stone.hum
#   inflating: Humor,Hist,Media,Food/strine.txt
#   inflating: Humor,Hist,Media,Food/strsdiet.txt
#   inflating: Humor,Hist,Media,Food/st_silic.txt
#   inflating: Humor,Hist,Media,Food/studentb.txt
#   inflating: Humor,Hist,Media,Food/subrdead.hum
#   inflating: Humor,Hist,Media,Food/suicide2.txt
#   inflating: Humor,Hist,Media,Food/sungenu.hum
#   inflating: Humor,Hist,Media,Food/supermar.rul
#   inflating: Humor,Hist,Media,Food/swearfrn.hum
#   inflating: Humor,Hist,Media,Food/sysadmin.txt
#   inflating: Humor,Hist,Media,Food/sysman.txt
#   inflating: Humor,Hist,Media,Food/t-10.hum
#   inflating: Humor,Hist,Media,Food/takenote.jok
#   inflating: Humor,Hist,Media,Food/talebeat.hum
#   inflating: Humor,Hist,Media,Food/talkbizr.txt
#   inflating: Humor,Hist,Media,Food/taping.hum
#   inflating: Humor,Hist,Media,Food/tarot.txt
#   inflating: Humor,Hist,Media,Food/teens.txt
#   inflating: Humor,Hist,Media,Food/telecom.q
#   inflating: Humor,Hist,Media,Food/televisi.hum
#   inflating: Humor,Hist,Media,Food/televisi.txt
#   inflating: Humor,Hist,Media,Food/temphell.jok
#   inflating: Humor,Hist,Media,Food/terbear.txt
#   inflating: Humor,Hist,Media,Food/termpoem.txt
#   inflating: Humor,Hist,Media,Food/terms.hum
#   inflating: Humor,Hist,Media,Food/test.hum
#   inflating: Humor,Hist,Media,Food/test.jok
#   inflating: Humor,Hist,Media,Food/test2.jok
#   inflating: Humor,Hist,Media,Food/testchri.txt
#   inflating: Humor,Hist,Media,Food/texican.dic
#   inflating: Humor,Hist,Media,Food/texican.lex
#   inflating: Humor,Hist,Media,Food/textgrap.hum
#   inflating: Humor,Hist,Media,Food/tfepisod.hum
#   inflating: Humor,Hist,Media,Food/tfpoems.hum
#   inflating: Humor,Hist,Media,Food/thecube.hum
#   inflating: Humor,Hist,Media,Food/the_math.hel
#   inflating: Humor,Hist,Media,Food/thermite.ana
#   inflating: Humor,Hist,Media,Food/tickmoon.hum
#   inflating: Humor,Hist,Media,Food/timetr.hum
#   inflating: Humor,Hist,Media,Food/tnd.1
#   inflating: Humor,Hist,Media,Food/top10.elf
#   inflating: Humor,Hist,Media,Food/top10.txt
#   inflating: Humor,Hist,Media,Food/top10st1.txt
#   inflating: Humor,Hist,Media,Food/top10st2.txt
#   inflating: Humor,Hist,Media,Food/topten.hum
#   inflating: Humor,Hist,Media,Food/transp.txt
#   inflating: Humor,Hist,Media,Food/shorties.jok
#   inflating: Humor,Hist,Media,Food/shrink.news
#   inflating: Humor,Hist,Media,Food/shuttleb.hum
#   inflating: Humor,Hist,Media,Food/signatur.jok
#   inflating: Humor,Hist,Media,Food/sigs.txt
#   inflating: Humor,Hist,Media,Food/sinksub.txt
#   inflating: Humor,Hist,Media,Food/skincat
#   inflating: Humor,Hist,Media,Food/skippy.hum
#   inflating: Humor,Hist,Media,Food/skippy.txt
#   inflating: Humor,Hist,Media,Food/slogans.txt
#   inflating: Humor,Hist,Media,Food/smackjok.hum
#   inflating: Humor,Hist,Media,Food/smartass.txt
#   inflating: Humor,Hist,Media,Food/smiley.txt
#   inflating: Humor,Hist,Media,Food/smokers.txt
#   inflating: Humor,Hist,Media,Food/smurf_co.txt
#   inflating: Humor,Hist,Media,Food/smurfkil.hum
#   inflating: Humor,Hist,Media,Food/smurfs.cc
#   inflating: Humor,Hist,Media,Food/puzzle.spo
#   inflating: Humor,Hist,Media,Food/python_s.ong
#   inflating: Humor,Hist,Media,Food/q.pun
#   inflating: Humor,Hist,Media,Food/quack26.txt
#   inflating: Humor,Hist,Media,Food/quantum.jok
#   inflating: Humor,Hist,Media,Food/quest.hum
#   inflating: Humor,Hist,Media,Food/quick.jok
#   inflating: Humor,Hist,Media,Food/quotes.bug
#   inflating: Humor,Hist,Media,Food/quotes.jok
#   inflating: Humor,Hist,Media,Food/quotes.txt
#   inflating: Humor,Hist,Media,Food/rabbit.txt
#   inflating: Humor,Hist,Media,Food/racist.net
#   inflating: Humor,Hist,Media,Food/radiolaf.hum
#   inflating: Humor,Hist,Media,Food/rapmastr.hum
#   inflating: Humor,Hist,Media,Food/ratings.hum
#   inflating: Humor,Hist,Media,Food/ratspit.hum
#   inflating: Humor,Hist,Media,Food/raven.hum
#   inflating: Humor,Hist,Media,Food/readme.bat
#   inflating: Humor,Hist,Media,Food/reagan.hum
#   inflating: Humor,Hist,Media,Food/realest.txt
#   inflating: Humor,Hist,Media,Food/reasons.txt
#   inflating: Humor,Hist,Media,Food/rec.por
#   inflating: Humor,Hist,Media,Food/record_.gap
#   inflating: Humor,Hist,Media,Food/reddwarf.sng
#   inflating: Humor,Hist,Media,Food/reddye.hum
#   inflating: Humor,Hist,Media,Food/red-neck.jks
#   inflating: Humor,Hist,Media,Food/rednecks.txt
#   inflating: Humor,Hist,Media,Food/relative.ada
#   inflating: Humor,Hist,Media,Food/religion.txt
#   inflating: Humor,Hist,Media,Food/renorthr.txt
#   inflating: Humor,Hist,Media,Food/rent-a_cat
#   inflating: Humor,Hist,Media,Food/rentals.hum
#   inflating: Humor,Hist,Media,Food/report.hum
#   inflating: Humor,Hist,Media,Food/residncy.jok
#   inflating: Humor,Hist,Media,Food/resolutn.txt
#   inflating: Humor,Hist,Media,Food/resrch_p.hra
#   inflating: Humor,Hist,Media,Food/resrch_phrase
#   inflating: Humor,Hist,Media,Food/revolt.dj
#   inflating: Humor,Hist,Media,Food/rinaldos.law
#   inflating: Humor,Hist,Media,Food/rinaldos.txt
#   inflating: Humor,Hist,Media,Food/ripoffpc.hum
#   inflating: Humor,Hist,Media,Food/roach.asc
#   inflating: Humor,Hist,Media,Food/roadpizz.txt
#   inflating: Humor,Hist,Media,Food/robot.tes
#   inflating: Humor,Hist,Media,Food/rocking.hum
#   inflating: Humor,Hist,Media,Food/rockmus.hum
#   inflating: Humor,Hist,Media,Food/poopie.txt
#   inflating: Humor,Hist,Media,Food/popconc.hum
#   inflating: Humor,Hist,Media,Food/popmach
#   inflating: Humor,Hist,Media,Food/post.nuc
#   inflating: Humor,Hist,Media,Food/potty.txt
#   inflating: Humor,Hist,Media,Food/pournell.spo
#   inflating: Humor,Hist,Media,Food/prac1.jok
#   inflating: Humor,Hist,Media,Food/prac2.jok
#   inflating: Humor,Hist,Media,Food/prac3.jok
#   inflating: Humor,Hist,Media,Food/prac4.jok
#   inflating: Humor,Hist,Media,Food/pracjoke.txt
#   inflating: Humor,Hist,Media,Food/practica.txt
#   inflating: Humor,Hist,Media,Food/prawblim.hum
#   inflating: Humor,Hist,Media,Food/prayer.hum
#   inflating: Humor,Hist,Media,Food/primes.jok
#   inflating: Humor,Hist,Media,Food/princess.brd
#   inflating: Humor,Hist,Media,Food/problem.txt
#   inflating: Humor,Hist,Media,Food/pro-fact.hum
#   inflating: Humor,Hist,Media,Food/progrs.gph
#   inflating: Humor,Hist,Media,Food/proof.met
#   inflating: Humor,Hist,Media,Food/prooftec.txt
#   inflating: Humor,Hist,Media,Food/proposal.jok
#   inflating: Humor,Hist,Media,Food/psalm.reagan
#   inflating: Humor,Hist,Media,Food/psalm23.txt
#   inflating: Humor,Hist,Media,Food/psalm_nixon
#   inflating: Humor,Hist,Media,Food/psalm_re.aga
#   inflating: Humor,Hist,Media,Food/psilaine.hum
#   inflating: Humor,Hist,Media,Food/psycho.txt
#   inflating: Humor,Hist,Media,Food/pukeprom.jok
#   inflating: Humor,Hist,Media,Food/pun.txt
#   inflating: Humor,Hist,Media,Food/pure.mat
#   inflating: Humor,Hist,Media,Food/netnews.10
#   inflating: Humor,Hist,Media,Food/newconst.hum
#   inflating: Humor,Hist,Media,Food/newmex.hum
#   inflating: Humor,Hist,Media,Food/news.hum
#   inflating: Humor,Hist,Media,Food/nigel.1
#   inflating: Humor,Hist,Media,Food/nigel.2
#   inflating: Humor,Hist,Media,Food/nigel.3
#   inflating: Humor,Hist,Media,Food/nigel.4
#   inflating: Humor,Hist,Media,Food/nigel.5
#   inflating: Humor,Hist,Media,Food/nigel.6
#   inflating: Humor,Hist,Media,Food/nigel.7
#   inflating: Humor,Hist,Media,Food/nigel.10
#   inflating: Humor,Hist,Media,Food/nigel10.txt
#   inflating: Humor,Hist,Media,Food/nihgel_8.9
#   inflating: Humor,Hist,Media,Food/normal.boy
#   inflating: Humor,Hist,Media,Food/normalboy.txt
#   inflating: Humor,Hist,Media,Food/nosuch_nasfic
#   inflating: Humor,Hist,Media,Food/novel.hum
#   inflating: Humor,Hist,Media,Food/nuke.hum
#   inflating: Humor,Hist,Media,Food/nukeplay.hum
#   inflating: Humor,Hist,Media,Food/nukewar.txt
#   inflating: Humor,Hist,Media,Food/nukwaste
#   inflating: Humor,Hist,Media,Food/number
#   inflating: Humor,Hist,Media,Food/number.killer
#   inflating: Humor,Hist,Media,Food/number_k.ill
#   inflating: Humor,Hist,Media,Food/nurds.hum
#   inflating: Humor,Hist,Media,Food/nysucks.hum
#   inflating: Humor,Hist,Media,Food/oam.nfo
#   inflating: Humor,Hist,Media,Food/oam-001.txt
#   inflating: Humor,Hist,Media,Food/oasis
#   inflating: Humor,Hist,Media,Food/odd_to.obs
#   inflating: Humor,Hist,Media,Food/office.txt
#   inflating: Humor,Hist,Media,Food/ohandre.hum
#   inflating: Humor,Hist,Media,Food/old.txt
#   inflating: Humor,Hist,Media,Food/oldeng.hum
#   inflating: Humor,Hist,Media,Food/oldtime.sng
#   inflating: Humor,Hist,Media,Food/one.par
#   inflating: Humor,Hist,Media,Food/onetoone.hum
#   inflating: Humor,Hist,Media,Food/onetotwo.hum
#   inflating: Humor,Hist,Media,Food/ookpik.hum
#   inflating: Humor,Hist,Media,Food/opinion.hum
#   inflating: Humor,Hist,Media,Food/oracle.jok
#   inflating: Humor,Hist,Media,Food/o-ttalk.hum
#   inflating: Humor,Hist,Media,Food/ourfathr.txt
#   inflating: Humor,Hist,Media,Food/outawork.erl
#   inflating: Humor,Hist,Media,Food/oxymoron.jok
#   inflating: Humor,Hist,Media,Food/oxymoron.txt
#   inflating: Humor,Hist,Media,Food/ozarks.hum
#   inflating: Humor,Hist,Media,Food/paddingurpapers.txt
#   inflating: Humor,Hist,Media,Food/parabl.hum
#   inflating: Humor,Hist,Media,Food/passage.hum
#   inflating: Humor,Hist,Media,Food/peanuts.txt
#   inflating: Humor,Hist,Media,Food/peatchp.hum
#   inflating: Humor,Hist,Media,Food/pecker.txt
#   inflating: Humor,Hist,Media,Food/pepsideg.txt
#   inflating: Humor,Hist,Media,Food/phony.hum
#   inflating: Humor,Hist,Media,Food/phorse.hum
#   inflating: Humor,Hist,Media,Food/pickup.txt
#   inflating: Humor,Hist,Media,Food/pipespec.txt
#   inflating: Humor,Hist,Media,Food/pizzawho.hum
#   inflating: Humor,Hist,Media,Food/planeget.hum
#   inflating: Humor,Hist,Media,Food/p-law.hum
#   inflating: Humor,Hist,Media,Food/pol-corr.txt
#   inflating: Humor,Hist,Media,Food/polemom.txt
#   inflating: Humor,Hist,Media,Food/poli.tics
#   inflating: Humor,Hist,Media,Food/poli_t.ics
#   inflating: Humor,Hist,Media,Food/polly_.new
#   inflating: Humor,Hist,Media,Food/deep.txt
#   inflating: Humor,Hist,Media,Food/deterior.hum
#   inflating: Humor,Hist,Media,Food/diesmurf.txt
#   inflating: Humor,Hist,Media,Food/dieter.txt
#   inflating: Humor,Hist,Media,Food/dingding.hum
#   inflating: Humor,Hist,Media,Food/dirtword.txt
#   inflating: Humor,Hist,Media,Food/disaster.hum
#   inflating: Humor,Hist,Media,Food/disclmr.txt
#   inflating: Humor,Hist,Media,Food/disclym.txt
#   inflating: Humor,Hist,Media,Food/d-ned.hum
#   inflating: Humor,Hist,Media,Food/docdict.txt
#   inflating: Humor,Hist,Media,Food/doc-says.txt
#   inflating: Humor,Hist,Media,Food/docspeak.txt
#   inflating: Humor,Hist,Media,Food/doggun.sto
#   inflating: Humor,Hist,Media,Food/donut.txt
#   inflating: Humor,Hist,Media,Food/dover.poem
#   inflating: Humor,Hist,Media,Food/drinker.txt
#   inflating: Humor,Hist,Media,Food/drinking.tro
#   inflating: Humor,Hist,Media,Food/drinkrul.jok
#   inflating: Humor,Hist,Media,Food/dromes.txt
#   inflating: Humor,Hist,Media,Food/druggame.hum
#   inflating: Humor,Hist,Media,Food/drunk.txt
#   inflating: Humor,Hist,Media,Food/dthought.txt
#   inflating: Humor,Hist,Media,Food/dubltalk.jok
#   inflating: Humor,Hist,Media,Food/eandb.drx
#   inflating: Humor,Hist,Media,Food/eatme.txt
#   inflating: Humor,Hist,Media,Food/electric.txt
#   inflating: Humor,Hist,Media,Food/element.jok
#   inflating: Humor,Hist,Media,Food/elephant.fun
#   inflating: Humor,Hist,Media,Food/elevator.fun
#   inflating: Humor,Hist,Media,Food/engineer.hum
#   inflating: Humor,Hist,Media,Food/english
#   inflating: Humor,Hist,Media,Food/engrhyme.txt
#   inflating: Humor,Hist,Media,Food/enlightenment.txt
#   inflating: Humor,Hist,Media,Food/enquire.hum
#   inflating: Humor,Hist,Media,Food/epitaph
#   inflating: Humor,Hist,Media,Food/eskimo.nel
#   inflating: Humor,Hist,Media,Food/exam.50
#   inflating: Humor,Hist,Media,Food/excuse.txt
#   inflating: Humor,Hist,Media,Food/excuse30.txt
#   inflating: Humor,Hist,Media,Food/excuses.txt
#   inflating: Humor,Hist,Media,Food/failure.txt
#   inflating: Humor,Hist,Media,Food/farsi.phrase
#   inflating: Humor,Hist,Media,Food/farsi.txt
#   inflating: Humor,Hist,Media,Food/fartinfo.txt
#   inflating: Humor,Hist,Media,Food/fartting.txt
#   inflating: Humor,Hist,Media,Food/fascist.txt
#   inflating: Humor,Hist,Media,Food/fbipizza.txt
#   inflating: Humor,Hist,Media,Food/fed.txt
#   inflating: Humor,Hist,Media,Food/feggaqui.txt
#   inflating: Humor,Hist,Media,Food/fegg!int.txt
#   inflating: Humor,Hist,Media,Food/feggmagi.txt
#   inflating: Humor,Hist,Media,Food/female.jok
#   inflating: Humor,Hist,Media,Food/figure_1.txt
#   inflating: Humor,Hist,Media,Food/fireplacein.txt
#   inflating: Humor,Hist,Media,Food/firstaid.inf
#   inflating: Humor,Hist,Media,Food/firstaid.txt
#   inflating: Humor,Hist,Media,Food/flattax.hum
#   inflating: Humor,Hist,Media,Food/flowchrt
#   inflating: Humor,Hist,Media,Food/flowchrt.txt
#   inflating: Humor,Hist,Media,Food/flux_fix.txt
#   inflating: Humor,Hist,Media,Food/footfun.hum
#   inflating: Humor,Hist,Media,Food/free-cof.fee
#   inflating: Humor,Hist,Media,Food/freshman.hum
#   inflating: Humor,Hist,Media,Food/freudonseuss.txt
#   inflating: Humor,Hist,Media,Food/from.hum
#   inflating: Humor,Hist,Media,Food/f_tang.txt
#   inflating: Humor,Hist,Media,Food/fuck!.txt
#   inflating: Humor,Hist,Media,Food/fuckyou2.txt
#   inflating: Humor,Hist,Media,Food/fusion.sup
#   inflating: Humor,Hist,Media,Food/fwksfun.hum
#   inflating: Humor,Hist,Media,Food/gaiahuma
#   inflating: Humor,Hist,Media,Food/ganamembers.txt
#   inflating: Humor,Hist,Media,Food/gas.txt
#   inflating: Humor,Hist,Media,Food/gd_guide.txt
#   inflating: Humor,Hist,Media,Food/german.aut
#   inflating: Humor,Hist,Media,Food/girlspeak.txt
#   inflating: Humor,Hist,Media,Food/goforth.hum
#   inflating: Humor,Hist,Media,Food/gohome.hum
#   inflating: Humor,Hist,Media,Food/gown.txt
#   inflating: Humor,Hist,Media,Food/grail.txt
#   inflating: Humor,Hist,Media,Food/grammar.jok
#   inflating: Humor,Hist,Media,Food/grommet.hum
#   inflating: Humor,Hist,Media,Food/grospoem.txt
#   inflating: Humor,Hist,Media,Food/growth.txt
#   inflating: Humor,Hist,Media,Food/hack
#   inflating: Humor,Hist,Media,Food/hacktest.txt
#   inflating: Humor,Hist,Media,Food/harmful.hum
#   inflating: Humor,Hist,Media,Food/headlnrs
#   inflating: Humor,Hist,Media,Food/hecomes.jok
#   inflating: Humor,Hist,Media,Food/height.txt
#   inflating: Humor,Hist,Media,Food/hell.jok
#   inflating: Humor,Hist,Media,Food/hell.txt
#   inflating: Humor,Hist,Media,Food/herb!.hum
#   inflating: Humor,Hist,Media,Food/hi.tec
#   inflating: Humor,Hist,Media,Food/hierarch.txt
#   inflating: Humor,Hist,Media,Food/hilbilly.wri
#   inflating: Humor,Hist,Media,Food/history2.oop
#   inflating: Humor,Hist,Media,Food/hitler.59
#   inflating: Humor,Hist,Media,Food/hitler.txt
#   inflating: Humor,Hist,Media,Food/hitlerap.txt
#   inflating: Humor,Hist,Media,Food/hoonsrc.txt
#   inflating: Humor,Hist,Media,Food/hoosier.txt
#   inflating: Humor,Hist,Media,Food/horoscop.jok
#   inflating: Humor,Hist,Media,Food/horoscop.txt
#   inflating: Humor,Hist,Media,Food/horoscope.txt
#   inflating: Humor,Hist,Media,Food/hotel.txt
#   inflating: Humor,Hist,Media,Food/hotnnot.hum
#   inflating: Humor,Hist,Media,Food/how.bugs.breakd
#   inflating: Humor,Hist,Media,Food/how2bgod.txt
#   inflating: Humor,Hist,Media,Food/howlong.hum
#   inflating: Humor,Hist,Media,Food/how_to_i.pro
#   inflating: Humor,Hist,Media,Food/hstlrtxt.txt
#   inflating: Humor,Hist,Media,Food/htswfren.txt
#   inflating: Humor,Hist,Media,Food/hum2
#   inflating: Humor,Hist,Media,Food/humatra.txt
#   inflating: Humor,Hist,Media,Food/humatran.jok
#   inflating: Humor,Hist,Media,Food/humor9.txt
#   inflating: Humor,Hist,Media,Food/humpty.dumpty
#   inflating: Humor,Hist,Media,Food/icm.hum
#   inflating: Humor,Hist,Media,Food/idaho.txt
#   inflating: Humor,Hist,Media,Food/idr2.txt
#   inflating: Humor,Hist,Media,Food/imbecile.txt
#   inflating: Humor,Hist,Media,Food/imprrisk.hum
#   inflating: Humor,Hist,Media,Food/incarhel.hum
#   inflating: Humor,Hist,Media,Food/kaboom.hum
#   inflating: Humor,Hist,Media,Food/initials.rid
#   inflating: Humor,Hist,Media,Food/inlaws1.txt
#   inflating: Humor,Hist,Media,Food/inquirer.txt
#   inflating: Humor,Hist,Media,Food/insanity.hum
#   inflating: Humor,Hist,Media,Food/insult.lst
#   inflating: Humor,Hist,Media,Food/insults1.txt
#   inflating: Humor,Hist,Media,Food/insuranc.sty
#   inflating: Humor,Hist,Media,Food/insure.hum
#   inflating: Humor,Hist,Media,Food/interv.hum
#   inflating: Humor,Hist,Media,Food/investi.hum
#   inflating: Humor,Hist,Media,Food/iqtest
#   inflating: Humor,Hist,Media,Food/ivan.hum
#   inflating: Humor,Hist,Media,Food/jac&tuu.hum
#   inflating: Humor,Hist,Media,Food/jargon.phd
#   inflating: Humor,Hist,Media,Food/jason.fun
#   inflating: Humor,Hist,Media,Food/jc-elvis.inf
#   inflating: Humor,Hist,Media,Food/jeffie.heh
#   inflating: Humor,Hist,Media,Food/johann
#   inflating: Humor,Hist,Media,Food/jokeju07.txt
#   inflating: Humor,Hist,Media,Food/jokes
#   inflating: Humor,Hist,Media,Food/jokes.txt
#   inflating: Humor,Hist,Media,Food/jokes1.txt
#   inflating: Humor,Hist,Media,Food/just2
#   inflating: Humor,Hist,Media,Food/justify
#   inflating: Humor,Hist,Media,Food/kid2
#   inflating: Humor,Hist,Media,Food/kid_diet.txt
#   inflating: Humor,Hist,Media,Food/killer.hum
#   inflating: Humor,Hist,Media,Food/killself.hum
#   inflating: Humor,Hist,Media,Food/kilsmur.hum
#   inflating: Humor,Hist,Media,Food/kloo.txt
#   inflating: Humor,Hist,Media,Food/koans.txt
#   inflating: Humor,Hist,Media,Food/labels.txt
#   inflating: Humor,Hist,Media,Food/lampoon.jok
#   inflating: Humor,Hist,Media,Food/languag.jok
#   inflating: Humor,Hist,Media,Food/la_times.hun
#   inflating: Humor,Hist,Media,Food/law.sch
#   inflating: Humor,Hist,Media,Food/lawhunt.txt
#   inflating: Humor,Hist,Media,Food/laws.txt
#   inflating: Humor,Hist,Media,Food/lawskool.txt
#   inflating: Humor,Hist,Media,Food/lawsuniv.hum
#   inflating: Humor,Hist,Media,Food/lawyer.jok
#   inflating: Humor,Hist,Media,Food/lawyers.txt
#   inflating: Humor,Hist,Media,Food/lazarus.txt
#   inflating: Humor,Hist,Media,Food/leech.txt
#   inflating: Humor,Hist,Media,Food/let.go
#   inflating: Humor,Hist,Media,Food/letgosh.txt
#   inflating: Humor,Hist,Media,Food/letter.txt
#   inflating: Humor,Hist,Media,Food/letter_f.sch
#   inflating: Humor,Hist,Media,Food/libraway.txt
#   inflating: Humor,Hist,Media,Food/liceprof.sty
#   inflating: Humor,Hist,Media,Food/lifeimag.hum
#   inflating: Humor,Hist,Media,Food/lifeinfo.hum
#   inflating: Humor,Hist,Media,Food/lif&love.hum
#   inflating: Humor,Hist,Media,Food/limerick.jok
#   inflating: Humor,Hist,Media,Food/lines.jok
#   inflating: Humor,Hist,Media,Food/lion.jok
#   inflating: Humor,Hist,Media,Food/lion.txt
#   inflating: Humor,Hist,Media,Food/lions.cat
#   inflating: Humor,Hist,Media,Food/livnware.hum
#   inflating: Humor,Hist,Media,Food/llamas.txt
#   inflating: Humor,Hist,Media,Food/llong.hum
#   inflating: Humor,Hist,Media,Food/lobquad.hum
#   inflating: Humor,Hist,Media,Food/looser.hum
#   inflating: Humor,Hist,Media,Food/losers84.hum
#   inflating: Humor,Hist,Media,Food/losers86.hum
#   inflating: Humor,Hist,Media,Food/lotsa.jok
#   inflating: Humor,Hist,Media,Food/lozers
#   inflating: Humor,Hist,Media,Food/lozerzon.hum
#   inflating: Humor,Hist,Media,Food/lp-assoc.txt
#   inflating: Humor,Hist,Media,Food/lucky.cha
#   inflating: Humor,Hist,Media,Food/ludeinfo.hum
#   inflating: Humor,Hist,Media,Food/ludeinfo.txt
#   inflating: Humor,Hist,Media,Food/luvstory.txt
#   inflating: Humor,Hist,Media,Food/luzerzo2.hum
#   inflating: Humor,Hist,Media,Food/m0dzmen.hum
#   inflating: Humor,Hist,Media,Food/macsfarm.old
#   inflating: Humor,Hist,Media,Food/madhattr.jok
#   inflating: Humor,Hist,Media,Food/maecenas.hum
#   inflating: Humor,Hist,Media,Food/mailfrag.hum
#   inflating: Humor,Hist,Media,Food/makebeer.hum
#   inflating: Humor,Hist,Media,Food/making_y.wel
#   inflating: Humor,Hist,Media,Food/malechem.txt
#   inflating: Humor,Hist,Media,Food/manager.txt
#   inflating: Humor,Hist,Media,Food/manilla.hum
#   inflating: Humor,Hist,Media,Food/manners.txt
#   inflating: Humor,Hist,Media,Food/manspace.hum
#   inflating: Humor,Hist,Media,Food/marines.hum
#   inflating: Humor,Hist,Media,Food/marriage.hum
#   inflating: Humor,Hist,Media,Food/math.1
#   inflating: Humor,Hist,Media,Food/math.2
#   inflating: Humor,Hist,Media,Food/math.far
#   inflating: Humor,Hist,Media,Food/mcd.txt
#   inflating: Humor,Hist,Media,Food/meinkamp.hum
#   inflating: Humor,Hist,Media,Food/mel.txt
#   inflating: Humor,Hist,Media,Food/memo.hum
#   inflating: Humor,Hist,Media,Food/men&wome.txt
#   inflating: Humor,Hist,Media,Food/merry.txt
#   inflating: Humor,Hist,Media,Food/miamadvi.hum
#   inflating: Humor,Hist,Media,Food/miami.hum
#   inflating: Humor,Hist,Media,Food/miamimth.txt
#   inflating: Humor,Hist,Media,Food/middle.age
#   inflating: Humor,Hist,Media,Food/misc.1
#   inflating: Humor,Hist,Media,Food/misery.hum
#   inflating: Humor,Hist,Media,Food/missheav.hum
#   inflating: Humor,Hist,Media,Food/modstup
#   inflating: Humor,Hist,Media,Food/montpyth.hum
#   inflating: Humor,Hist,Media,Food/moonshin
#   inflating: Humor,Hist,Media,Food/moose.txt
#   inflating: Humor,Hist,Media,Food/moslem.txt
#   inflating: Humor,Hist,Media,Food/mothers.txt
#   inflating: Humor,Hist,Media,Food/motrbike.jok
#   inflating: Humor,Hist,Media,Food/mowers.txt
#   inflating: Humor,Hist,Media,Food/mr.rogers
#   inflating: Humor,Hist,Media,Food/mrscienc.hum
#   inflating: Humor,Hist,Media,Food/mtm.hum
#   inflating: Humor,Hist,Media,Food/murph.jok
#   inflating: Humor,Hist,Media,Food/murphy.txt
#   inflating: Humor,Hist,Media,Food/murphy_l.txt
#   inflating: Humor,Hist,Media,Food/murphys.txt
#   inflating: Humor,Hist,Media,Food/mutate.hum
#   inflating: Humor,Hist,Media,Food/myheart.hum
#   inflating: Humor,Hist,Media,Food/naivewiz.hum
#   inflating: Humor,Hist,Media,Food/nasaglenn.txt
#   inflating: Humor,Hist,Media,Food/aclamt.txt
#   inflating: Humor,Hist,Media,Food/acronym.lis
#   inflating: Humor,Hist,Media,Food/acronym.txt
#   inflating: Humor,Hist,Media,Food/acronyms.txt
#   inflating: Humor,Hist,Media,Food/adcopy.hum
#   inflating: Humor,Hist,Media,Food/addrmeri.txt
#   inflating: Humor,Hist,Media,Food/admin.txt
#   inflating: Humor,Hist,Media,Food/age.txt
#   inflating: Humor,Hist,Media,Food/aggie.txt
#   inflating: Humor,Hist,Media,Food/aids.txt
#   inflating: Humor,Hist,Media,Food/airlines
#   inflating: Humor,Hist,Media,Food/alabama.txt
#   inflating: Humor,Hist,Media,Food/alcatax.txt
#   inflating: Humor,Hist,Media,Food/alflog.txt
#   inflating: Humor,Hist,Media,Food/ambrose.bie
#   inflating: Humor,Hist,Media,Food/amchap2.txt
#   inflating: Humor,Hist,Media,Food/anim_lif.txt
#   inflating: Humor,Hist,Media,Food/annoy.fascist
#   inflating: Humor,Hist,Media,Food/answers
#   inflating: Humor,Hist,Media,Food/anthropo.stu
#   inflating: Humor,Hist,Media,Food/arab.dic
#   inflating: Humor,Hist,Media,Food/argotdic.txt
#   inflating: Humor,Hist,Media,Food/art-fart.hum
#   inflating: Humor,Hist,Media,Food/atombomb.hum
#   inflating: Humor,Hist,Media,Food/att.txt
#   inflating: Humor,Hist,Media,Food/aussie.lng
#   inflating: Humor,Hist,Media,Food/b-2.jok
#   inflating: Humor,Hist,Media,Food/bad
#   inflating: Humor,Hist,Media,Food/bad.jok
#   inflating: Humor,Hist,Media,Food/bad-d
#   inflating: Humor,Hist,Media,Food/badday.hum
#   inflating: Humor,Hist,Media,Food/bagelope.txt
#   inflating: Humor,Hist,Media,Food/bank.rob
#   inflating: Humor,Hist,Media,Food/barney.cn1
#   inflating: Humor,Hist,Media,Food/barney.txt
#   inflating: Humor,Hist,Media,Food/bb
#   inflating: Humor,Hist,Media,Food/bbq.txt
#   inflating: Humor,Hist,Media,Food/beapimp.hum
#   inflating: Humor,Hist,Media,Food/beave.hum
#   inflating: Humor,Hist,Media,Food/beer.hum
#   inflating: Humor,Hist,Media,Food/beerdiag.txt
#   inflating: Humor,Hist,Media,Food/bible.txt
#   inflating: Humor,Hist,Media,Food/bigpic1.hum
#   inflating: Humor,Hist,Media,Food/billcat.hum
#   inflating: Humor,Hist,Media,Food/bimg.prn
#   inflating: Humor,Hist,Media,Food/bitchcar.hum
#   inflating: Humor,Hist,Media,Food/blackapp.hum
#   inflating: Humor,Hist,Media,Food/blackhol.hum
#   inflating: Humor,Hist,Media,Food/blaster.hum
#   inflating: Humor,Hist,Media,Food/bless.bc
#   inflating: Humor,Hist,Media,Food/blooprs1.asc
#   inflating: Humor,Hist,Media,Food/bmdn01.txt
#   inflating: Humor,Hist,Media,Food/boatmemo.jok
#   inflating: Humor,Hist,Media,Food/boe.hum
#   inflating: Humor,Hist,Media,Food/boneles2.txt
#   inflating: Humor,Hist,Media,Food/bored.txt
#   inflating: Humor,Hist,Media,Food/browneco.hum
#   inflating: Humor,Hist,Media,Food/btcisfre.hum
#   inflating: Humor,Hist,Media,Food/bugbreak.hum
#   inflating: Humor,Hist,Media,Food/bugs.txt
#   inflating: Humor,Hist,Media,Food/butwrong.hum
#   inflating: Humor,Hist,Media,Food/buzzword.hum
#   inflating: Humor,Hist,Media,Food/bw-phwan.hat
#   inflating: Humor,Hist,Media,Food/bw-summe.hat
#   inflating: Humor,Hist,Media,Food/cabbage.txt
#   inflating: Humor,Hist,Media,Food/calculus.txt
#   inflating: Humor,Hist,Media,Food/calif.hum
#   inflating: Humor,Hist,Media,Food/calvin.txt
#   inflating: Humor,Hist,Media,Food/cancer.rat
#   inflating: Humor,Hist,Media,Food/cars.txt
#   inflating: Humor,Hist,Media,Food/cartoon.law
#   inflating: Humor,Hist,Media,Food/cartoon.laws
#   inflating: Humor,Hist,Media,Food/cartoon_laws.txt
#   inflating: Humor,Hist,Media,Food/cartwb.son
#   inflating: Humor,Hist,Media,Food/catballs.hum
#   inflating: Humor,Hist,Media,Food/catin.hat
#   inflating: Humor,Hist,Media,Food/catranch.hum
#   inflating: Humor,Hist,Media,Food/catstory.txt
#   inflating: Humor,Hist,Media,Food/cbmatic.hum
#   inflating: Humor,Hist,Media,Food/cform2.txt
#   inflating: Humor,Hist,Media,Food/change.hum
#   inflating: Humor,Hist,Media,Food/cheapin.la
#   inflating: Humor,Hist,Media,Food/chickens.jok
#   inflating: Humor,Hist,Media,Food/childhoo.jok
#   inflating: Humor,Hist,Media,Food/childrenbooks.txt
#   inflating: Humor,Hist,Media,Food/chinesec.hum
#   inflating: Humor,Hist,Media,Food/chunnel.txt
#   inflating: Humor,Hist,Media,Food/church.sto
#   inflating: Humor,Hist,Media,Food/climbing.let
#   inflating: Humor,Hist,Media,Food/co-car.jok
#   inflating: Humor,Hist,Media,Food/cockney.alp
#   inflating: Humor,Hist,Media,Food/coffee.txt
#   inflating: Humor,Hist,Media,Food/coffeebeerwomen.txt
#   inflating: Humor,Hist,Media,Food/cogdis.txt
#   inflating: Humor,Hist,Media,Food/cold.fus
#   inflating: Humor,Hist,Media,Food/coldfake.hum
#   inflating: Humor,Hist,Media,Food/collected_quotes.txt
#   inflating: Humor,Hist,Media,Food/college.hum
#   inflating: Humor,Hist,Media,Food/college.sla
#   inflating: Humor,Hist,Media,Food/college.txt
#   inflating: Humor,Hist,Media,Food/commutin.jok
#   inflating: Humor,Hist,Media,Food/computer.txt
#   inflating: Humor,Hist,Media,Food/comrevi1.hum
#   inflating: Humor,Hist,Media,Food/conan.txt
#   inflating: Humor,Hist,Media,Food/confucius_say.txt
#   inflating: Humor,Hist,Media,Food/consp.txt
#   inflating: Humor,Hist,Media,Food/contract.moo
#   inflating: Humor,Hist,Media,Food/cookie.1
#   inflating: Humor,Hist,Media,Food/critic.txt
#   inflating: Humor,Hist,Media,Food/coollngo2.txt
#   inflating: Humor,Hist,Media,Food/cooplaws
#   inflating: Humor,Hist,Media,Food/cops.txt
#   inflating: Humor,Hist,Media,Food/corporat.txt
#   inflating: Humor,Hist,Media,Food/court.quips
#   inflating: Humor,Hist,Media,Food/cowexplo.hum
#   inflating: Humor,Hist,Media,Food/coyote.txt
#   inflating: Humor,Hist,Media,Food/cuchy.hum
#   inflating: Humor,Hist,Media,Food/cucumber.jok
#   inflating: Humor,Hist,Media,Food/cucumber.txt
#   inflating: Humor,Hist,Media,Food/curiousgeorgie.txt
#   inflating: Humor,Hist,Media,Food/curse.txt
#   inflating: Humor,Hist,Media,Food/dark.suc
#   inflating: Humor,Hist,Media,Food/dead2.txt
#   inflating: Humor,Hist,Media,Food/dead3.txt
#   inflating: Humor,Hist,Media,Food/dead5.txt
#   inflating: Humor,Hist,Media,Food/dead-r
#   inflating: Humor,Hist,Media,Food/deathhem.txt
#   inflating: Humor,Hist,Media,Food/adameve.hum
#   inflating: Humor,Hist,Media,Food/bingbong.hum
#   inflating: Humor,Hist,Media,Food/brainect.hum
#   inflating: Humor,Hist,Media,Food/charity.hum
#   inflating: Humor,Hist,Media,Food/cheapfar.hum
#   inflating: Humor,Hist,Media,Food/drugshum.hum
#   inflating: Humor,Hist,Media,Food/ghostfun.hum
#   inflating: Humor,Hist,Media,Food/hammock.hum
#   inflating: Humor,Hist,Media,Food/packard.txt
#   inflating: Humor,Hist,Media,Food/memory.hum
#   inflating: Humor,Hist,Media,Food/mlverb.hum
#   inflating: Humor,Hist,Media,Food/modest.hum
#   inflating: Humor,Hist,Media,Food/poets.hum
#   inflating: Humor,Hist,Media,Food/reconcil.hum
#   inflating: Humor,Hist,Media,Food/saveface.hum
#   inflating: Humor,Hist,Media,Food/shameonu.hum
#   inflating: Humor,Hist,Media,Food/solders.hum
#   inflating: Humor,Hist,Media,Food/spacever.hum
#   inflating: Humor,Hist,Media,Food/symbol.hum
#   inflating: Humor,Hist,Media,Food/watchlip.hum
#   inflating: Humor,Hist,Media,Food/weights.hum
#   inflating: Humor,Hist,Media,Food/whatthe.hum
#   inflating: Humor,Hist,Media,Food/1st_aid.txt
#   inflating: Humor,Hist,Media,Food/acetab1.txt
#   inflating: Humor,Hist,Media,Food/acne1.txt
#   inflating: Humor,Hist,Media,Food/alcohol.hum
#   inflating: Humor,Hist,Media,Food/all_grai
#   inflating: Humor,Hist,Media,Food/aniherb.txt
#   inflating: Humor,Hist,Media,Food/antibiot.txt
#   inflating: Humor,Hist,Media,Food/antimead.bev
#   inflating: Humor,Hist,Media,Food/aphrodis.txt
#   inflating: Humor,Hist,Media,Food/appbred.brd
#   inflating: Humor,Hist,Media,Food/appetiz.rcp
#   inflating: Humor,Hist,Media,Food/applepie.des
#   inflating: Humor,Hist,Media,Food/apsaucke.des
#   inflating: Humor,Hist,Media,Food/arcadian.txt
#   inflating: Humor,Hist,Media,Food/atherosc.txt
#   inflating: Humor,Hist,Media,Food/awespinh.sal
#   inflating: Humor,Hist,Media,Food/ayurved.txt
#   inflating: Humor,Hist,Media,Food/b12.txt
#   inflating: Humor,Hist,Media,Food/back1.txt
#   inflating: Humor,Hist,Media,Food/bakebred.txt
#   inflating: Humor,Hist,Media,Food/baklava.des
#   inflating: Humor,Hist,Media,Food/banana01.brd
#   inflating: Humor,Hist,Media,Food/banana02.brd
#   inflating: Humor,Hist,Media,Food/banana03.brd
#   inflating: Humor,Hist,Media,Food/banana04.brd
#   inflating: Humor,Hist,Media,Food/banana05.brd
#   inflating: Humor,Hist,Media,Food/batrbred.txt
#   inflating: Humor,Hist,Media,Food/beer.gam
#   inflating: Humor,Hist,Media,Food/beer.txt
#   inflating: Humor,Hist,Media,Food/beer-g
#   inflating: Humor,Hist,Media,Food/beergame.hum
#   inflating: Humor,Hist,Media,Food/beergame.txt
#   inflating: Humor,Hist,Media,Food/beer-gui
#   inflating: Humor,Hist,Media,Food/beershrm.fis
#   inflating: Humor,Hist,Media,Food/beershrp.fis
#   inflating: Humor,Hist,Media,Food/beerwarn.txt
#   inflating: Humor,Hist,Media,Food/beginn.ers
#   inflating: Humor,Hist,Media,Food/berryeto.bev
#   inflating: Humor,Hist,Media,Food/bhang.fun
#   inflating: Humor,Hist,Media,Food/bhb.ill
#   inflating: Humor,Hist,Media,Food/blkbean.txt
#   inflating: Humor,Hist,Media,Food/blkbnsrc.vgn
#   inflating: Humor,Hist,Media,Food/blood.txt
#   inflating: Humor,Hist,Media,Food/boarchil.txt
#   inflating: Humor,Hist,Media,Food/bond-2.txt
#   inflating: Humor,Hist,Media,Food/booknuti.txt
#   inflating: Humor,Hist,Media,Food/booze.fun
#   inflating: Humor,Hist,Media,Food/booze1.fun
#   inflating: Humor,Hist,Media,Food/booze2.fun
#   inflating: Humor,Hist,Media,Food/brdpudd.des
#   inflating: Humor,Hist,Media,Food/bread.rcp
#   inflating: Humor,Hist,Media,Food/bread.rec
#   inflating: Humor,Hist,Media,Food/bread.txt
#   inflating: Humor,Hist,Media,Food/breadpud.des
#   inflating: Humor,Hist,Media,Food/brush1.txt
#   inflating: Humor,Hist,Media,Food/btaco.txt
#   inflating: Humor,Hist,Media,Food/btscke01.des
#   inflating: Humor,Hist,Media,Food/btscke03.des
#   inflating: Humor,Hist,Media,Food/btscke04.des
#   inflating: Humor,Hist,Media,Food/btscke05.des
#   inflating: Humor,Hist,Media,Food/bunacald.fis
#   inflating: Humor,Hist,Media,Food/burrito.mea
#   inflating: Humor,Hist,Media,Food/butcher.txt
#   inflating: Humor,Hist,Media,Food/butstcod.fis
#   inflating: Humor,Hist,Media,Food/byfb.txt
#   inflating: Humor,Hist,Media,Food/caesardr.sal
#   inflating: Humor,Hist,Media,Food/calamus.hrb
#   inflating: Humor,Hist,Media,Food/candy.txt
#   inflating: Humor,Hist,Media,Food/candybar.fun
#   inflating: Humor,Hist,Media,Food/capital.txt
#   inflating: Humor,Hist,Media,Food/caramels.des
#   inflating: Humor,Hist,Media,Food/cereal.txt
#   inflating: Humor,Hist,Media,Food/chili.txt
#   inflating: Humor,Hist,Media,Food/chinese.txt
#   inflating: Humor,Hist,Media,Food/choco-ch.ips
#   inflating: Humor,Hist,Media,Food/cmu.share
#   inflating: Humor,Hist,Media,Food/coffee.faq
#   inflating: Humor,Hist,Media,Food/coke.fun
#   inflating: Humor,Hist,Media,Food/coke.txt
#   inflating: Humor,Hist,Media,Food/coke1
#   inflating: Humor,Hist,Media,Food/coke_fan.naz
#   inflating: Humor,Hist,Media,Food/cokeform.txt
#   inflating: Humor,Hist,Media,Food/coladrik.fun
#   inflating: Humor,Hist,Media,Food/coladrik.txt
#   inflating: Humor,Hist,Media,Food/cookberk
#   inflating: Humor,Hist,Media,Food/cookbkly.how
#   inflating: Humor,Hist,Media,Food/cooking.fun
#   inflating: Humor,Hist,Media,Food/cooking.jok
#   inflating: Humor,Hist,Media,Food/cuisine.txt
#   inflating: Humor,Hist,Media,Food/curry.hrb
#   inflating: Humor,Hist,Media,Food/curry.txt
#   inflating: Humor,Hist,Media,Food/damiana.hrb
#   inflating: Humor,Hist,Media,Food/dandwine.bev
#   inflating: Humor,Hist,Media,Food/dining.out
#   inflating: Humor,Hist,Media,Food/drinks.txt
#   inflating: Humor,Hist,Media,Food/egg-bred.txt
#   inflating: Humor,Hist,Media,Food/egglentl.vgn
#   inflating: Humor,Hist,Media,Food/eggroll1.mea
#   inflating: Humor,Hist,Media,Food/engmuffn.txt
#   inflating: Humor,Hist,Media,Food/fajitas.rcp
#   inflating: Humor,Hist,Media,Food/fearcola.hum
#   inflating: Humor,Hist,Media,Food/feista01.dip
#   inflating: Humor,Hist,Media,Food/fiber.txt
#   inflating: Humor,Hist,Media,Food/firecamp.txt
#   inflating: Humor,Hist,Media,Food/fish.rec
#   inflating: Humor,Hist,Media,Food/focaccia.brd
#   inflating: Humor,Hist,Media,Food/foodtips
#   inflating: Humor,Hist,Media,Food/fudge.txt
#   inflating: Humor,Hist,Media,Food/gack!.txt
#   inflating: Humor,Hist,Media,Food/get.drunk.cheap
#   inflating: Humor,Hist,Media,Food/goldwatr.txt
#   inflating: Humor,Hist,Media,Food/gotukola.hrb
#   inflating: Humor,Hist,Media,Food/greenchi.txt
#   inflating: Humor,Hist,Media,Food/hamburge.nam
#   inflating: Humor,Hist,Media,Food/hedgehog.txt
#   inflating: Humor,Hist,Media,Food/homebrew.txt
#   inflating: Humor,Hist,Media,Food/hop.faq
#   inflating: Humor,Hist,Media,Food/hotpeper.txt
#   inflating: Humor,Hist,Media,Food/iced.tea
#   inflating: Humor,Hist,Media,Food/indgrdn.txt
#   inflating: Humor,Hist,Media,Food/insect1.txt
#   inflating: Humor,Hist,Media,Food/jalapast.dip
#   inflating: Humor,Hist,Media,Food/jambalay.pol
#   inflating: Humor,Hist,Media,Food/jawgumbo.fis
#   inflating: Humor,Hist,Media,Food/jawsalad.fis
#   inflating: Humor,Hist,Media,Food/jerky.rcp
#   inflating: Humor,Hist,Media,Food/jungjuic.bev
#   inflating: Humor,Hist,Media,Food/kashrut.txt
#   inflating: Humor,Hist,Media,Food/margos.txt
#   inflating: Humor,Hist,Media,Food/mead.rcp
#   inflating: Humor,Hist,Media,Food/meat2.txt
#   inflating: Humor,Hist,Media,Food/mitch.txt
#   inflating: Humor,Hist,Media,Food/montoys.txt
#   inflating: Humor,Hist,Media,Food/mrsfield
#   inflating: Humor,Hist,Media,Food/msfields.txt
#   inflating: Humor,Hist,Media,Food/newcoke.txt
#   inflating: Humor,Hist,Media,Food/nzdrinks.txt
#   inflating: Humor,Hist,Media,Food/oakwood.txt
#   inflating: Humor,Hist,Media,Food/oatbran.rec
#   inflating: Humor,Hist,Media,Food/oculis.rcp
#   inflating: Humor,Hist,Media,Food/oldtime.txt
#   inflating: Humor,Hist,Media,Food/oranchic.pol
#   inflating: Humor,Hist,Media,Food/parsnip.txt
#   inflating: Humor,Hist,Media,Food/pasta001.sal
#   inflating: Humor,Hist,Media,Food/pbcookie.des
#   inflating: Humor,Hist,Media,Food/penndtch
#   inflating: Humor,Hist,Media,Food/pepper.txt
#   inflating: Humor,Hist,Media,Food/pot.txt
#   inflating: Humor,Hist,Media,Food/ppbeer.txt
#   inflating: Humor,Hist,Media,Food/qttofu.vgn
#   inflating: Humor,Hist,Media,Food/quantity.001
#   inflating: Humor,Hist,Media,Food/recepies.fun
#   inflating: Humor,Hist,Media,Food/recip1.txt
#   inflating: Humor,Hist,Media,Food/recipe.001
#   inflating: Humor,Hist,Media,Food/recipe.002
#   inflating: Humor,Hist,Media,Food/recipe.003
#   inflating: Humor,Hist,Media,Food/recipe.004
#   inflating: Humor,Hist,Media,Food/recipe.005
#   inflating: Humor,Hist,Media,Food/recipe.006
#   inflating: Humor,Hist,Media,Food/recipe.007
#   inflating: Humor,Hist,Media,Food/recipe.009
#   inflating: Humor,Hist,Media,Food/recipe.010
#   inflating: Humor,Hist,Media,Food/recipe.011
#   inflating: Humor,Hist,Media,Food/recipe.012
#   inflating: Humor,Hist,Media,Food/renored.txt
#   inflating: Humor,Hist,Media,Food/richbred.txt
#   inflating: Humor,Hist,Media,Food/sanshop.txt
#   inflating: Humor,Hist,Media,Food/seafood.txt
#   inflating: Humor,Hist,Media,Food/seeds42.txt
#   inflating: Humor,Hist,Media,Food/shooters.txt
#   inflating: Humor,Hist,Media,Food/strattma.txt
#   inflating: Humor,Hist,Media,Food/tuna.lab
#   inflating: Humor,Hist,Media,Food/turkey.fun
#   inflating: Humor,Hist,Media,Food/twinkies.jok
#   inflating: Humor,Hist,Media,Food/venganza.txt
#   inflating: Humor,Hist,Media,Food/venison.txt
#   inflating: Humor,Hist,Media,Food/whitbred.txt
#   inflating: Humor,Hist,Media,Food/wonton.txt
#   inflating: Humor,Hist,Media,Food/woods.txt
#   inflating: Humor,Hist,Media,Food/x-drinks.txt
#   inflating: Humor,Hist,Media,Food/yogurt.asc
#   inflating: Humor,Hist,Media,Food/zucantom.sal
#   inflating: Humor,Hist,Media,Food/zuccmush.sal
#   inflating: Humor,Hist,Media,Food/films_gl.txt
#   inflating: Humor,Hist,Media,Food/stuf10.txt
#   inflating: Humor,Hist,Media,Food/stuf11.txt
#   inflating: Humor,Hist,Media,Food/bnbeg2.4.txt
#   inflating: Humor,Hist,Media,Food/beauty.tm
#   inflating: Humor,Hist,Media,Food/cultmov.faq
#   inflating: Humor,Hist,Media,Food/tpquotes.txt
#   inflating: Humor,Hist,Media,Food/anime.cli
#   inflating: Humor,Hist,Media,Food/aeonint.txt
#   inflating: Humor,Hist,Media,Food/crzycred.lst
#   inflating: Humor,Hist,Media,Food/gameshow.txt
#   inflating: Humor,Hist,Media,Food/allusion
#   inflating: Humor,Hist,Media,Food/oliver02.txt
#   inflating: Humor,Hist,Media,Food/sw_err.txt
#   inflating: Humor,Hist,Media,Food/sf-zine.pub
#   inflating: Humor,Hist,Media,Food/commword.hum
#   inflating: Humor,Hist,Media,Food/anime.lif
#   inflating: Humor,Hist,Media,Food/classicm.hum
#   inflating: Humor,Hist,Media,Food/japantv.txt
#   inflating: Humor,Hist,Media,Food/christop.int
#   inflating: Humor,Hist,Media,Food/homermmm.txt
#   inflating: Humor,Hist,Media,Food/kanalx.txt
#   inflating: Humor,Hist,Media,Food/arnold.txt
#   inflating: Humor,Hist,Media,Food/facedeth.txt
#   inflating: Humor,Hist,Media,Food/clancy.txt
#   inflating: Humor,Hist,Media,Food/wacky.ani
#   inflating: Humor,Hist,Media,Food/rns_bwl.txt
#   inflating: Humor,Hist,Media,Food/sfmovie.txt
#   inflating: Humor,Hist,Media,Food/normquot.txt
#   inflating: Humor,Hist,Media,Food/bbh_intv.txt
#   inflating: Humor,Hist,Media,Food/mov_rail.txt
#   inflating: Humor,Hist,Media,Food/cast.lis
#   inflating: Humor,Hist,Media,Food/a_tv_t-p.com
#   inflating: Humor,Hist,Media,Food/bnb_quot.txt
#   inflating: Humor,Hist,Media,Food/ads.txt
#   inflating: Humor,Hist,Media,Food/adrian_e.faq
#   inflating: Humor,Hist,Media,Food/rns_bcl.txt
#   inflating: Humor,Hist,Media,Food/earp
#   inflating: Humor,Hist,Media,Food/petshop
#   inflating: Humor,Hist,Media,Food/letterbx.txt
#   inflating: Humor,Hist,Media,Food/cgs_lst.txt
#   inflating: Humor,Hist,Media,Food/hitchcoc.app
#   inflating: Humor,Hist,Media,Food/hitchcok.txt
#   inflating: Humor,Hist,Media,Food/aboutada.txt
#   inflating: Humor,Hist,Media,Food/widows
#   inflating: Humor,Hist,Media,Food/how2dotv.txt
#   inflating: Humor,Hist,Media,Food/tpquote2.txt
#   inflating: Humor,Hist,Media,Food/bozo_tv.leg
#   inflating: Humor,Hist,Media,Food/namm
#   inflating: Humor,Hist,Media,Food/a_fish_c.apo
#   inflating: Humor,Hist,Media,Food/adt_miam.txt
#   inflating: Humor,Hist,Media,Food/gd_ql.txt
#   inflating: Humor,Hist,Media,Food/twilight.txt
#   inflating: Humor,Hist,Media,Food/epi_tton.txt
#   inflating: Humor,Hist,Media,Food/epi_.txt
#   inflating: Humor,Hist,Media,Food/lost.txt
#   inflating: Humor,Hist,Media,Food/gd_hhead.txt
#   inflating: Humor,Hist,Media,Food/scratchy.txt
#   inflating: Humor,Hist,Media,Food/epi_merm.txt
#   inflating: Humor,Hist,Media,Food/comic_st.gui
#   inflating: Humor,Hist,Media,Food/bnbguide.txt
#   inflating: Humor,Hist,Media,Food/amazing.epi
#   inflating: Humor,Hist,Media,Food/allfam.epi
#   inflating: Humor,Hist,Media,Food/epi_bnb.txt
#   inflating: Humor,Hist,Media,Food/gd_tznew.txt
#   inflating: Humor,Hist,Media,Food/a-team
#   inflating: Humor,Hist,Media,Food/ateam.epi
#   inflating: Humor,Hist,Media,Food/epi_rns.txt
#   inflating: Humor,Hist,Media,Food/wkrp.epi
#   inflating: Humor,Hist,Media,Food/episimp2.txt
#   inflating: Humor,Hist,Media,Food/gd_ol.txt
#   inflating: Humor,Hist,Media,Food/gd_drwho.txt
#   inflating: Humor,Hist,Media,Food/gd_sgrnd.txt
#   inflating: Humor,Hist,Media,Food/blake7.lis
#   inflating: Humor,Hist,Media,Food/gd_frasr.txt
#   inflating: Humor,Hist,Media,Food/blackadd
#   inflating: Humor,Hist,Media,Food/bbc_vide.cat
#   inflating: Humor,Hist,Media,Food/epiquest.txt
#   inflating: Humor,Hist,Media,Food/avengers.lis
#   inflating: Humor,Hist,Media,Food/highland.epi
#   inflating: Humor,Hist,Media,Food/maxheadr
#   inflating: Humor,Hist,Media,Food/buldrwho.txt
#   inflating: Humor,Hist,Media,Food/gd_maxhd.txt
#   inflating: Humor,Hist,Media,Food/ghostsch.hum
#   inflating: Humor,Hist,Media,Food/crazy.txt
#   inflating: Humor,Hist,Media,Food/moore.txt
#   inflating: Humor,Hist,Media,Food/msorrow
#   inflating: Humor,Hist,Media,Food/tribble.hum
#   inflating: Humor,Hist,Media,Food/tshirts.jok
#   inflating: Humor,Hist,Media,Food/tuflife.txt
#   inflating: Humor,Hist,Media,Food/un.happy
#   inflating: Humor,Hist,Media,Food/units.mea
#   inflating: Humor,Hist,Media,Food/various.txt
#   inflating: Humor,Hist,Media,Food/wagit.txt
#   inflating: Humor,Hist,Media,Food/worldend.hum
#   inflating: Humor,Hist,Media,Food/soleleer.hum
#   inflating: Humor,Hist,Media,Food/soporifi.abs
#   inflating: Humor,Hist,Media,Food/sorority.gir
#   inflating: Humor,Hist,Media,Food/teevee.hum
#   inflating: Humor,Hist,Media,Food/terrmcd'.hum
#   inflating: Humor,Hist,Media,Food/terrnieg.hum
#   inflating: Humor,Hist,Media,Food/the_ant.txt
#   inflating: Humor,Hist,Media,Food/thesis.beh
#   inflating: Humor,Hist,Media,Food/toxcwast.hum
#   inflating: Humor,Hist,Media,Food/simp.txt
#   inflating: Humor,Hist,Media,Food/smurf-03.txt
#   inflating: Humor,Hist,Media,Food/puzzles.jok
#   inflating: Humor,Hist,Media,Food/quantum.phy
#   inflating: Humor,Hist,Media,Food/quux_p.oem
#   inflating: Humor,Hist,Media,Food/repair.hum
#   inflating: Humor,Hist,Media,Food/research.hum
#   inflating: Humor,Hist,Media,Food/rinaldo.jok
#   inflating: Humor,Hist,Media,Food/popmusi.hum
#   inflating: Humor,Hist,Media,Food/prover.wisom
#   inflating: Humor,Hist,Media,Food/prover_w.iso
#   inflating: Humor,Hist,Media,Food/psych_pr.quo
#   inflating: Humor,Hist,Media,Food/nintendo.jok
#   inflating: Humor,Hist,Media,Food/nukewar.jok
#   inflating: Humor,Hist,Media,Food/odearakk.hum
#   inflating: Humor,Hist,Media,Food/oilgluts.hum
#   inflating: Humor,Hist,Media,Food/passenge.sim
#   inflating: Humor,Hist,Media,Food/penisprt.txt
#   inflating: Humor,Hist,Media,Food/phunatdi.ana
#   inflating: Humor,Hist,Media,Food/pickup.lin
#   inflating: Humor,Hist,Media,Food/policpig.hum
#   inflating: Humor,Hist,Media,Food/poll2res.hum
#   inflating: Humor,Hist,Media,Food/polly.txt
#   inflating: Humor,Hist,Media,Food/defectiv.hum
#   inflating: Humor,Hist,Media,Food/desk.txt
#   inflating: Humor,Hist,Media,Food/devils.jok
#   inflating: Humor,Hist,Media,Food/drive.txt
#   inflating: Humor,Hist,Media,Food/dym
#   inflating: Humor,Hist,Media,Food/econridl.fun
#   inflating: Humor,Hist,Media,Food/empeval.txt
#   inflating: Humor,Hist,Media,Food/english.txt
#   inflating: Humor,Hist,Media,Food/final-ex.txt
#   inflating: Humor,Hist,Media,Food/finalexm.hum
#   inflating: Humor,Hist,Media,Food/forsooth.hum
#   inflating: Humor,Hist,Media,Food/fusion.gal
#   inflating: Humor,Hist,Media,Food/godmonth.txt
#   inflating: Humor,Hist,Media,Food/good.txt
#   inflating: Humor,Hist,Media,Food/hate.hum
#   inflating: Humor,Hist,Media,Food/impurmat.hum
#   inflating: Humor,Hist,Media,Food/ins1
#   inflating: Humor,Hist,Media,Food/insult
#   inflating: Humor,Hist,Media,Food/is_story.txt
#   inflating: Humor,Hist,Media,Food/italoink.txt
#   inflating: Humor,Hist,Media,Food/japrap.hum
#   inflating: Humor,Hist,Media,Food/jrrt.riddle
#   inflating: Humor,Hist,Media,Food/lbinter.hum
#   inflating: Humor,Hist,Media,Food/legal.hum
#   inflating: Humor,Hist,Media,Food/lll.hum
#   inflating: Humor,Hist,Media,Food/lozeuser.hum
#   inflating: Humor,Hist,Media,Food/luggage.hum
#   inflating: Humor,Hist,Media,Food/madscrib.hum
#   inflating: Humor,Hist,Media,Food/mash.hum
#   inflating: Humor,Hist,Media,Food/melodram.hum
#   inflating: Humor,Hist,Media,Food/mensroom.jok
#   inflating: Humor,Hist,Media,Food/miranda.hum
#   inflating: Humor,Hist,Media,Food/mundane.v2
#   inflating: Humor,Hist,Media,Food/mydaywss.hum
#   inflating: Humor,Hist,Media,Food/abbott.txt
#   inflating: Humor,Hist,Media,Food/advrtize.txt
#   inflating: Humor,Hist,Media,Food/beerjesus.hum
#   inflating: Humor,Hist,Media,Food/bitnet.txt
#   inflating: Humor,Hist,Media,Food/boston.geog
#   inflating: Humor,Hist,Media,Food/carowner.txt
#   inflating: Humor,Hist,Media,Food/cartoon_.txt
#   inflating: Humor,Hist,Media,Food/chainltr.txt
#   inflating: Humor,Hist,Media,Food/dead4.txt
#   inflating: Humor,Hist,Media,Food/analogy.hum
#   inflating: Humor,Hist,Media,Food/parades.hum
#   inflating: Humor,Hist,Media,Food/throwawa.hum
#   inflating: Humor,Hist,Media,Food/anorexia.txt
#   inflating: Humor,Hist,Media,Food/arthriti.txt
#   inflating: Humor,Hist,Media,Food/beesherb.txt
#   inflating: Humor,Hist,Media,Food/bredcake.des
#   inflating: Humor,Hist,Media,Food/brewing
#   inflating: Humor,Hist,Media,Food/brownie.rec
#   inflating: Humor,Hist,Media,Food/btscke02.des
#   inflating: Humor,Hist,Media,Food/buffwing.pol
#   inflating: Humor,Hist,Media,Food/bw.txt
#   inflating: Humor,Hist,Media,Food/cake.rec
#   inflating: Humor,Hist,Media,Food/chickens.txt
#   inflating: Humor,Hist,Media,Food/diet.txt
#   inflating: Humor,Hist,Media,Food/drinks.gui
#   inflating: Humor,Hist,Media,Food/food
#   inflating: Humor,Hist,Media,Food/frogeye1.sal
#   inflating: Humor,Hist,Media,Food/garlpast.vgn
#   inflating: Humor,Hist,Media,Food/gingbeer.txt
#   inflating: Humor,Hist,Media,Food/gumbo.txt
#   inflating: Humor,Hist,Media,Food/hangover.txt
#   inflating: Humor,Hist,Media,Food/japice.bev
#   inflating: Humor,Hist,Media,Food/orgfrost.bev
#   inflating: Humor,Hist,Media,Food/recipe.008
#   inflating: Humor,Hist,Media,Food/scam.txt
#   inflating: Humor,Hist,Media,Food/shuimai.txt
#   inflating: Humor,Hist,Media,Food/snapple.rum
#   inflating: Humor,Hist,Media,Food/stagline.txt
#   inflating: Humor,Hist,Media,Food/texbeef.txt
#   inflating: Humor,Hist,Media,Food/vegan.rcp
#   inflating: Humor,Hist,Media,Food/filmgoof.txt
#   inflating: Humor,Hist,Media,Food/epikarat.txt
#   inflating: Humor,Hist,Media,Food/rns_ency.txt
#   inflating: Humor,Hist,Media,Food/chung.iv
#   inflating: Humor,Hist,Media,Food/gd_flybd.txt
#   inflating: Humor,Hist,Media,Food/oliver.txt
#   inflating: Humor,Hist,Media,Food/subb_lis.txt
#   inflating: Humor,Hist,Media,Food/horflick.txt
#   inflating: Humor,Hist,Media,Food/twinpeak.txt
#   inflating: Humor,Hist,Media,Food/missdish
#   inflating: Humor,Hist,Media,Food/hbo_spec.rev
#   inflating: Humor,Hist,Media,Food/mtv.asc
#   inflating: Humor,Hist,Media,Food/gd_gal.txt
#   inflating: Humor,Hist,Media,Food/gd_alf.txt
#   inflating: Humor,Hist,Media,Food/outlimit.txt
#   inflating: Humor,Hist,Media,Food/gd_liqtv.txt

# %% [markdown]
# # Preprocessing

# %%
FILE_PATH = 'Humor,Hist,Media,Food/'
# FILE_NAME = 'apsnet.txt'
# with open(FILE_PATH + FILE_NAME, 'r') as f:
#   data = f.read()

# %% [markdown]
# ## Expanding Contractions & Unidecode

# %%
# !pip install contractions
# !pip install Unidecode
# Out:
# Collecting contractions
#   Downloading contractions-0.1.66-py2.py3-none-any.whl (8.0 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.21-py2.py3-none-any.whl (7.5 kB)
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 5.6 MB/s
# Collecting anyascii
#   Downloading anyascii-0.3.0-py3-none-any.whl (284 kB)
#      |████████████████████████████████| 284 kB 41.3 MB/s
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.0 contractions-0.1.66 pyahocorasick-1.4.4 textsearch-0.0.21
# Collecting Unidecode
#   Downloading Unidecode-1.3.3-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 4.2 MB/s
# Installing collected packages: Unidecode
# Successfully installed Unidecode-1.3.3

# %%
import contractions, unidecode

# %%
# data = unidecode.unidecode(contractions.fix(data))

# %% [markdown]
# ## Tokenizing

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')  # for tokenization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# tokenized_data = word_tokenize(data)

# %% [markdown]
# ## Remove Punctuations

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# def remove_punctuations(data):
#   return [word for word in data if word.isalpha()]

# no_punctuations = remove_punctuations(tokenized_data)
# no_punctuations

# %% [markdown]
# ## Remove Stopwords & Remove Whitespace

# %%
nltk.download('stopwords')  # for filtering stop words
from nltk.corpus import stopwords
STOP_WORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# filtered_data = [word.strip() for word in no_punctuations if word not in STOP_WORDS]
# filtered_data

# %% [markdown]
# ## Lemmatization & Lower Case

# %%
from nltk.stem.wordnet import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# LEMMATIZER = WordNetLemmatizer()
# lem_sent = [LEMMATIZER.lemmatize(words_sent).lower() for words_sent in filtered_data]
# print(lem_sent)

# %% [markdown]
# ## Combined Steps

# %%
from nltk.stem import PorterStemmer
# self.tokens[i] = ps.stem(self.tokens[i]);

# %%
def remove_punctuation(data):
  symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
  for i in range(len(symbols)):
      data = data.replace(symbols[i], ' ')
      data = data.replace("  ", " ")
  data = data.replace(',', ' ')
  return data

# %%
# Out:
# True

# %%
def preprocessing(data):
  LEMMATIZER = WordNetLemmatizer()
  ps = PorterStemmer()
  tokens = word_tokenize(unidecode.unidecode(contractions.fix(remove_punctuation(data))))

  preprocessed_tokens = [LEMMATIZER.lemmatize(word.strip()).lower() for word in tokens if word.isalpha() and word.lower() not in STOP_WORDS]
  # preprocessed_tokens = [ps.stem(word.strip()).lower() for word in tokens if word.isalpha() and word not in STOP_WORDS]
  return preprocessed_tokens

# %% [markdown]
# # Inverted Index Data Structure

# %%
def get_data(file_name):
  with open(FILE_PATH + file_name, 'r') as f:
    return f.read()

# %%
from os import listdir
FILE_LIST = listdir(FILE_PATH)
inverted_index = {}
for document_id in range(len(FILE_LIST)):
  document = FILE_LIST[document_id]
  try:
    tokens = list(set(preprocessing(get_data(document)))) # get unique tokens only
  except UnicodeDecodeError:
    data = open(FILE_PATH + document, 'rb').read().decode('ISO-8859-1')
    tokens = list(set(preprocessing(data)))
  for token in tokens:
    if token in inverted_index.keys():
      inverted_index[token][0] += 1
      inverted_index[token][1].append(document_id)
    else:
      inverted_index[token] = [1,[document_id]]

# %%
inverted_index.keys()
# Out:
# dict_keys(['vented', 'feminine', 'chanting', 'theme', 'lovable', 'elderly', 'itellectual', 'tool', 'ruminative', 'helped', 'hole', 'tether', 'tide', 'loan', 'hay', 'all', 'saint', 'handed', 'extending', 'pulled', 'ear', 'arsenical', 'favourite', 'swallowed', 'faddist', 'scholar', 'level', 'ken', 'nimepen', 'health', 'jile', 'surely', 'ommy', 'ark', 'big', 'neurotic', 'yegottny', 'sane', 'dimension', 'greetings', 'effortlessly', 'lep', 'chesty', 'sank', 'fleet', 'semmitch', 'fro', 'hour', 'living', 'december', 'provocative', 'click', 'zize', 'watser', 'anthem', 'mouse', 'threw', 'sell', 'looking', 'attack', 'sense', 'tribe', 'quoted', 'left', 'hear', 'yeggowan', 'pullets', 'capital', 'mountain', 'particular', 'coupler', 'induce', 'jumpy', 'close', 'aqua', 'shop', 'brannies', 'hembairg', 'cable', 'trump', 'ant', 'government', 'indeed', 'second', 'his', 'meagre', 'reveals', 'travelling', 'struggle', 'pay', 'went', 'forgotten', 'appearance', 'fipes', 'tiles', 'stoppem', 'jans', 'child', 'prosperous', 'durberville', 'spy', 'dicey', 'folk', 'respecting', 'slightly', 'breathtakingly', 'fair', 'saul', 'full', 'mood', 'key', 'bore', 'sneezing', 'war', 'realistic', 'circumstance', 'order', 'among', 'whose', 'psyche', 'cleanliness', 'creeping', 'taboo', 'eddy', 'scrabbled', 'ninner', 'rent', 'alarm', 'associations', 'smen', 'must', 'lazy', 'responsible', 'nark', 'la', 'mind', 'tear', 'shirt', 'furry', 'horror', 'matilda', 'dream', 'anf', 'synthetic', 'abat', 'tordan', 'nd', 'getcher', 'dairy', 'delight', 'mayhem', 'spoultered', 'wrapped', 'oh', 'everyday', 'language', 'mairlper', 'red', 'airman', 'paint', 'fillum', 'spurban', 'calculation', 'ritualistic', 'lee', 'spoken', 'antonym', 'mean', 'sairdy', 'chandelier', 'unique', 'lilma', 'putting', 'uncomfortable', 'hungry', 'nauseatingly', 'useful', 'ninter', 'quickly', 'coupla', 'go', 'hit', 'spin', 'cancel', 'tea', 'aged', 'colonel', 'fridy', 'main', 'wife', 'lemmyaf', 'decipher', 'remote', 'did', 'bandry', 'quaint', 'true', 'render', 'androgyne', 'adhesive', 'milk', 'woman', 'kelly', 'acre', 'gaudy', 'shaky', 'earthy', 'swissair', 'bess', 'bullet', 'new', 'tilda', 'autumn', 'pill', 'outgoing', 'follows', 'keyhole', 'watching', 'yer', 'temps', 'sentimental', 'virus', 'sledge', 'speed', 'spent', 'arber', 'settler', 'only', 'origin', 'thriving', 'when', 'discovery', 'orp', 'sarder', 'method', 'yet', 'cooling', 'remarkable', 'rocket', 'auburn', 'appear', 'underground', 'pain', 'exact', 'help', 'leaving', 'loose', 'fissroy', 'smith', 'increasingly', 'north', 'after', 'class', 'going', 'personal', 'livner', 'incident', 'beautiful', 'cowering', 'attempt', 'wiles', 'woo', 'obtain', 'french', 'issuing', 'how', 'they', 'gem', 'moat', 'literary', 'retail', 'do', 'shy', 'sponsor', 'snunner', 'huntsman', 'dry', 'dare', 'glass', 'democratic', 'its', 'shiving', 'overseas', 'little', 'painting', 'stewnce', 'cockle', 'dangerous', 'menai', 'lamp', 'mare', 'obscure', 'home', 'slennets', 'masculine', 'conjoined', 'alike', 'superphosphate', 'naw', 'taking', 'died', 'cholera', 'also', 'acquire', 'contributed', 'fierce', 'vaudeville', 'humana', 'rep', 'german', 'relating', 'tooth', 'jump', 'singer', 'refer', 'emeny', 'purple', 'publication', 'beckoned', 'dumb', 'momentarily', 'entangled', 'soprano', 'we', 'bronze', 'built', 'arrested', 'rest', 'parliamentary', 'composed', 'smeeide', 'dog', 'associated', 'collapse', 'waltzing', 'airp', 'dentist', 'response', 'wess', 'sitting', 'research', 'practically', 'wisspering', 'unstable', 'poisoner', 'maud', 'bark', 'knew', 'forever', 'welfare', 'wafer', 'uneasiness', 'forward', 'muffled', 'jeggoda', 'supernatural', 'bewildered', 'tree', 'established', 'rapes', 'congeal', 'restrained', 'fit', 'scone', 'teas', 'gom', 'gimmier', 'institution', 'up', 'expected', 'such', 'promiscuity', 'offensive', 'asians', 'various', 'tome', 'yeggo', 'rangs', 'conservative', 'murder', 'foo', 'territory', 'wodger', 'snore', 'covering', 'set', 'like', 'connoisseur', 'honey', 'raid', 'scona',  ...

# %%
# inverted_index['lion']
TOTAL_DOCS = len(FILE_LIST)

# %%
def handle_OR(l1, l2):
  l3 = []

  index1 = 0
  index2 = 0
  
  len1 = len(l1)
  len2 = len(l2)

  comparisons = 0

  while index1 < len1 and index2 < len2:
    if l1[index1] < l2[index2]:
      l3.append(l1[index1])
      index1 += 1
    elif l2[index2] < l1[index1]:
      l3.append(l2[index2])
      index2 += 1
    else:
      l3.append(l1[index1])
      index1 += 1
      index2 += 1
    
    comparisons += 1
  
  if index1 < len1:
    l3.extend(l1[index1:])
  
  if index2 < len2:
    l3.extend(l2[index2:])
  
  return l3, comparisons

def handle_AND(l1, l2):
  l3 = []

  index1 = 0
  index2 = 0
  
  len1 = len(l1)
  len2 = len(l2)

  comparisons = 0

  while index1 < len1 and index2 < len2:
    if l1[index1] < l2[index2]:
      index1 += 1
    elif l2[index2] < l1[index1]:
      index2 += 1
    else:
      l3.append(l1[index1])
      index1 += 1
      index2 += 1
    
    comparisons += 1
  return l3, comparisons

def handle_NOT(l):
  not_l = []
  prev_docid = 0
  for doc_id in l:
    not_l.extend([i for i in range(prev_docid+1, doc_id)])
    prev_docid = doc_id
  
  not_l.extend([i for i in range(prev_docid+1, TOTAL_DOCS+1)])
  return not_l, len(l)

def handle_AND_NOT(l1, l2):
  # 1 0 1
  # 1 1 0
  # 0 1 0
  # 0 0 0
  not_l, not_comparisons = handle_NOT(l2)
  l, and_comparisons = handle_AND(l1, not_l)
  return l, not_comparisons + and_comparisons

def handle_OR_NOT(l1, l2):
  # 1 0 1
  # 1 1 1
  # 0 1 0
  # 0 0 1
  not_l, not_comparisons = handle_NOT(l2)
  l, or_comparisons = handle_AND(l1, not_l) 
  return l, not_comparisons + or_comparisons

# %%
def handle_query(query, input_operation, inverted_index):
  query_list = preprocessing(query)

  if len(query_list) == 0:
    print("Invalid words in query")
    return [], 0

  if len(input_operation) != len(query_list) - 1:
    print("Invalid Number of Inputs")
    return [], 0
  
  tokens = []
  operation_list = []

  if query_list[0] in inverted_index.keys():
    tokens.append(query_list[0])

  for index in range(1, len(query_list)):
    if query_list[index] in inverted_index.keys():
      tokens.append(query_list[index])
      operation_list.append(input_operation[index-1])
    else:
      print(query_list[index], "is not present in the data structure")

  if len(tokens) < 2:
    print("Number of valid tokens are less than two")
    return [], 0

  if len(operation_list) != len(tokens)-1:
    operation_list = operation_list[1:]

  l1 = inverted_index[tokens[0]][1]
  # ASSUMPTION LEN(TOKENS) > 0

  total_comparisons = 0
  for i in range(len(operation_list)):
    operation = operation_list[i]

    operation_handler = {
        "AND": handle_AND,
        "OR": handle_OR,
        "AND NOT": handle_AND_NOT,
        "OR NOT": handle_OR_NOT
    }

    if operation not in operation_handler.keys():
      print("INVALID OPERATOR", operation)
      return [], 0
  
    l1, comparisons = operation_handler[operation](l1, inverted_index[tokens[i+1]][1])
    total_comparisons += comparisons
  return l1, total_comparisons


l1 = [1, 5, 8, 10, 11, 20]
l2 = [2, 4, 9, 11]
string = "Strangely names"
operations = ["OR NOT"]
ans, comparison = handle_query(string, operations, inverted_index)

# %%
query_num = input("Enter number of queries: ")
for i in range(int(query_num)):
  string = input("Input query: ")
  operations = input("Input operation sequence: ")

  ans, comparison = handle_query(string, operations.split(", "), inverted_index)

  print("Number of documents retrieved:", len(ans))
  print("Minimum number of comparisons:", comparison)
  print("List of document names:")
  doc_names = []
  for doc_id in ans:
    doc_names.append(FILE_LIST[doc_id])
  print(doc_names)
# Out:
# Enter number of queries: 1
# Input query: we're we're
# Input operation sequence: AND
# Invalid words in query
# Number of documents retrieved: 0
# Minimum number of comparisons: 0
# List of document names:
# []
